# %% [markdown]
# # Water Conservation Analysis Project Setup
#
# This notebook verifies that the Python environment is configured correctly and that required libraries import successfully.
#
# ## Project Stack
# - Python
# - Pandas
# - GeoPandas
# - NumPy
# - Matplotlib
# - Jupyter

# %%
import sys
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("GeoPandas:", gpd.__version__)
print("Environment ready!")
# Out:
# Python: 3.10.6 (tags/v3.10.6:9c7b4bd, Aug  1 2022, 21:53:49) [MSC v.1932 64 bit (AMD64)]
# Pandas: 2.3.3
# GeoPandas: 1.1.4
# Environment ready!
